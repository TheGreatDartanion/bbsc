# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('Prototypes-95d74ca67e5d.json',scope)
client = gspread.authorize(creds)

sheet = client.open('COVID-VA-Locality-Sheet').worksheet("Locality Decisions")

data_json = sheet.get_all_records()

# %%
result
# Out:
# [{'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes w/limited access',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Yes w/ some cancellations',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed until further notice',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Some parks are open; playgrounds, courts, and faculties are closed',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Limited service',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Albemarle County',
#   'Population': 109722,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.albemarle.org/navpages.asp?info=release&ID=24641'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Lodging Tax',
#   'Locality_Decision': 'Moratorium on penalties and interest; extension until June 30 to file',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Meals Tax',
#   'Locality_Decision': 'Moratorium on penalties and interest; extension until June 30 to file',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Property Tax',
#   'Locality_Decision': 'Extension to file for business personal property taxes',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Virtual',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'No',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'All locations closed until 3/31',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until further notice; by appointment only',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Unfenced parks, trails, and fields are open; All buildings, playgrounds, fenced fields, dog parks, courts, restrooms and parking lots are closed',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Reduced service on weekdays; fare collection suspended; Some WMATA stations are closed',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Trash/Recycling operating as normal; suspending yard waste and bulk material collection ',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections and waiving late fees',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Off Premise Alcohol Sales',
#   'Locality_Decision': 'Suspended enforcement of local restrictions on off premises alcohol sales and delivery',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Alexandria',
#   'Population': 159152,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Parking Changes',
#   'Locality_Decision': 'Suspended enforcement of parking restrictions for residential street sweeping and prohibition of 72 hour maximum ',
#   'Source': 'https://www.alexandriava.gov/Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Lodging Tax',
#   'Locality_Decision': 'No penalty or interest on taxes due b/w 3/13 and 4/30',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Meals Tax',
#   'Locality_Decision': 'No penalty or interest on taxes due b/w 3/13 and 4/30',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Parking Meters',
#   'Locality_Decision': 'Free short-term curbside parking outside businesses',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, closed to public',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled/Postponed',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed until further notice',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Open in limited capacity',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Open in very limited capacity',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Trails are open; All parks and facilities are closed',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'ART operating reduced service; Some WMATA stations are closed',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Regular collection services operating as normal; bulk trash collection suspended',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Virtual inspections only; online permitting only',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Arlington County',
#   'Population': 242152,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Parking Changes',
#   'Locality_Decision': 'Free short-term curbside parking outside businesses; Residential Parking Permit enforcement has been suspended',
#   'Source': 'https://health.arlingtonva.us/covid-19-coronavirus-updates/'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, closed to public',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes, limited',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed until further notice',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Trails and parks are open; Community center and aquatic center are closed',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Operating on a modified schedule',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Blacksburg',
#   'Population': 44563,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'No in person meetings, plans may be submitted online or in person with prior arrangement ',
#   'Source': 'https://www.blacksburg.gov/residents/public-health-and-safety/modified-town-services-and-operations'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, virtual',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'None',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until 3/29',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to Public until 3/29',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks and trails are open; playgrounds, tennis courts, basketball courts closed',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Charlottesville',
#   'Population': 49181,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.charlottesville.org/departments-and-services/departments-a-g/city-manager-s-office/communications/city-hall-updates-related-to-the-coronavirus-covid-19'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, with limited to public',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes, limited',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed until further notice',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until further notice; by appointment only',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks and trails are open, all facilities including playgrounds, shelters, courts and centers are closed',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Normal service, fare collection suspended',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Convenience centers operating as normal',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Chesterfield County',
#   'Population': 350760,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.chesterfield.gov/coronavirus'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Sales Tax (State)',
#   'Locality_Decision': 'Businesses can request to defer state sales tax payments due on 3/20/2020 for 30 days. Interest will accrue if extension is granted.  ',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Liberal telework policies; activated Public Health Emergency Leave; all official travel outside Virginia halted',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Library of Virginia closed through 4/30',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Capitol and Pocahontas Building closed until 3/30/20',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Limit Gatherings to 10 people, effective 3/24; Executive Order 53',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'All Virginia State Parks are open as of 3/23/20',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Public bodies are not allowed to hold virtual meetings solely by electronic communication  (March 20 opinion by Attorney General)',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Off Premise Alcohol Sales',
#   'Locality_Decision': 'Off-premise privileges allowed for curbside pickup',
#   'Source': 'NULL'},
#  {'Locality_Type': 'State',
#   'Locality_Name': 'Commonwealth of Virginia',
#   'Population': 8540000,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Small Business Loans (related to COVID-19)',
#   'Locality_Decision': 'Small businesses and nonprofit organizations throughout the Commonwealth affected by the COVID-19 public health crisis can now apply for low-interest federal disaster loans of up to $2 million from the SBA to pay fixed debts, payroll, accounts payable, and other expenses.',
#   'Source': 'NULL'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Property Tax',
#   'Locality_Decision': 'One month extension to file vehicle personal property; And to file for Business Personal Property Tax',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Real Estate Tax',
#   'Locality_Decision': 'One month extension of payment of first installment',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, closed to public,; online stream available',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed until further notice; wife still accessible from parking lots',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closing to public starting 3/27',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public starting 3/27 at 5pm; limited in person services as necessary',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Trails are open; All parks and amenities are closed',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Normal schedule: fare collection suspended; rear door boarding; Some WMATA stations closed',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'No changes to weekly collection schedule; Disposal centers open normal hours',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Fairfax County',
#   'Population': 1143528,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Applications accepted online or via drop-off; improved online accessibility; permits and inspections will still be processed',
#   'Source': 'https://www.fairfaxcounty.gov/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, virtual',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'All locations are closed',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until at least 3/29',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until at least 3/29',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'City beaches and outside parks remain open; all parks buildings are closed',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Hampton',
#   'Population': 135753,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Accepting online permit an inspection requests',
#   'Source': 'https://hampton.gov/CivicAlerts.aspx?AID=4417'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes w/ social distancing',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Yes w/ social distancing',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes w/ social distancing',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'All locations closed until 3/31',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public; by appointment only',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public; by appointment only',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks are open; all indoor facilities are closed',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Bus/paratransit service operating as scheduled; except for routes servicing JMU (closed), fare collection suspended',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Applications to be submitted online',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Harrisonburg',
#   'Population': 53997,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Small Business Loans (related to COVID-19)',
#   'Locality_Decision': 'The Harrisonburg Disaster Impact Loan Program will provide the interest free loans on a three-year term with no payments for 90 days after the loan funds are disbursed to the business. Businesses must have been established and operational in Harrisonburg for at least the previous six months, and eligible use of funds will include payroll, utilities, inventory and rent. Due to available funds, not all loans will be approved.',
#   'Source': 'https://www.harrisonburgva.gov/novel-coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Lodging Tax',
#   'Locality_Decision': 'No penalties or interest through August',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Meals Tax',
#   'Locality_Decision': 'No penalties or interest through August',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Property Tax',
#   'Locality_Decision': 'No penalties or interest for 60 days after June 5 for residents and businesses',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Real Estate Tax',
#   'Locality_Decision': 'No penalties or interest for 60 days after June 5 for residents and businesses',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, with limited to public',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Postponed',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes, limited',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed until further notice',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks and open spaces are open; Recreation and Parks buildings are closed',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Normal service, fare collection suspended',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Landfills open with reduced hours',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections; limited response for non-emergency needs',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Henrico County',
#   'Population': 328999,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Submit online or at dedicated drop stations; no fees are being collected; Remote review of plans; Inspections will continue with limited inspections in occupied structures',
#   'Source': 'https://henrico.us/coronavirus/'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Budget & Finance',
#   'Service': 'Change to Parking Meters',
#   'Locality_Decision': 'All street meters are free, 2 hour limit still applies',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Yes w/ some cancellations',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes, limited',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Closed until further notice',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Open',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Open',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks are open; all playgrounds, sports  courts, sports fields, skate parks, pavilions and dog parks are closed',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Suspension of bulk item collection; other operations are normal',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.leesburgva.gov/residents/coronavirus-information'},
#  {'Locality_Type': 'Town',
#   'Locality_Name': 'Leesburg',
#   'Population': 54215,
# ...
#   'Population': 465498,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://emergency.pwcgov.org/ https://emergency.pwcgov.org/agency-operational-status/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Prince William County',
#   'Population': 465498,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://emergency.pwcgov.org/ https://emergency.pwcgov.org/agency-operational-status/'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Prince William County',
#   'Population': 465498,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Applications are accepted via drop-off or mail services; plan reviews and inspections will continue',
#   'Source': 'https://emergency.pwcgov.org/ https://emergency.pwcgov.org/agency-operational-status/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'None',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'All library locations and book drops closed until 3/31',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until 3/31/2020',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to Public until 3/31',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks and trails are open; community centers are closed; dog parks are closed',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'GRTC: Normal service; fare collection suspended, including CARE until further notice',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Emergency services only; no disconnections',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Richmond',
#   'Population': 226841,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Parking Changes',
#   'Locality_Decision': 'No time violations enforced; only illegal parking enforced',
#   'Source': 'http://www.richmondgov.com/covid19/'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Yes, not open to public',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Employees still report as normal',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'All locations are closed; book drops remain available',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until 3/31',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until 3/31',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks and trails are open',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Suspending the Smartway Express Route; fare collections suspended',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Operating as normal; Transfer stations closed to residents',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Roanoke',
#   'Population': 99348,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Permits and plan reviews will be handled remotely; inspection and code enforcement will continue w/ social distance ',
#   'Source': 'https://www.roanokeva.gov/2566/Coronavirus-COVID-19'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Some cancellations, closed to public',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled/postponed',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'Locations and book drops closed until 4/23',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'Parks and trails are open; restrooms, pavilions, playgrounds closed',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Operating on modified schedule',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Landfills have reduced hours; closed Sundays and Mondays',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'County',
#   'Locality_Name': 'Stafford County',
#   'Population': 151689,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Submit online or by mail, drop-off by appointment only',
#   'Source': 'https://staffordcountyva.gov/2119/COVID-19-Coronavirus'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Governance',
#   'Service': 'Council/Board of Supervisors',
#   'Locality_Decision': 'Virtual',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Governance',
#   'Service': 'Other Boards/Commissions',
#   'Locality_Decision': 'Cancelled',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Human Resources ',
#   'Service': 'Tele-working Policy for C-19',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'In-Person Meetings',
#   'Locality_Decision': 'None',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Libraries',
#   'Locality_Decision': 'All locations and curbside services closed until April 15',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Municipal Building Open',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Office Hours',
#   'Locality_Decision': 'Closed to public until further notice',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Parks & Recreation',
#   'Locality_Decision': 'City parks remain open; Playgrounds, community centers and restrooms are closed',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Public Transportation',
#   'Locality_Decision': 'Normal service, fare collection suspended',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Trash/Recycling Collection',
#   'Locality_Decision': 'Operating as normal',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Utilities',
#   'Locality_Decision': 'Suspension of disconnections',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Operations ',
#   'Service': 'Virtual Meetings',
#   'Locality_Decision': 'Yes',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Planning & Zoning',
#   'Service': 'Temporary Permits for signage, etc.',
#   'Locality_Decision': 'Applications submitted by mail only; inspections limited to imminent safety complaints first',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'},
#  {'Locality_Type': 'City',
#   'Locality_Name': 'Staunton',
#   'Population': 24971,
#   'Service_Category': 'Small Business/ED',
#   'Service': 'Parking Changes',
#   'Locality_Decision': 'Discontinuation of parking fees in public parking garages and lots',
#   'Source': 'https://www.ci.staunton.va.us/departments/city-manager/covid-19-info'}]

# %%
import pandas as pd
data_df = pd.DataFrame(data_json)

# %%
data_df
# Out:
#     Locality Type     Locality Name  Population   Service Category  \
# 0          County  Albemarle County      109722         Governance
# 1          County  Albemarle County      109722         Governance
# 2          County  Albemarle County      109722   Human Resources
# 3          County  Albemarle County      109722        Operations
# 4          County  Albemarle County      109722        Operations
# ..            ...               ...         ...                ...
# 253          City          Staunton       24971        Operations
# 254          City          Staunton       24971        Operations
# 255          City          Staunton       24971        Operations
# 256          City          Staunton       24971  Planning & Zoning
# 257          City          Staunton       24971  Small Business/ED
#
#                                  Service  \
# 0           Council/Board of Supervisors
# 1               Other Boards/Commissions
# 2           Tele-working Policy for C-19
# 3                     In-Person Meetings
# 4                              Libraries
# ..                                   ...
# 253           Trash/Recycling Collection
# 254                            Utilities
# 255                     Virtual Meetings
# 256  Temporary Permits for signage, etc.
# 257                      Parking Changes
#
#                                      Locality Decision  \
# 0                                 Yes w/limited access
# 1                            Yes w/ some cancellations
# 2                                                  Yes
# 3                                                  Yes
# 4                          Closed until further notice
# ..                                                 ...
# 253                                Operating as normal
# 254                       Suspension of disconnections
# 255                                                Yes
# 256  Applications submitted by mail only; inspectio...
# 257  Discontinuation of parking fees in public park...
#
#                                                 Source
# 0    https://www.albemarle.org/navpages.asp?info=re...
# 1    https://www.albemarle.org/navpages.asp?info=re...
# 2    https://www.albemarle.org/navpages.asp?info=re...
# 3    https://www.albemarle.org/navpages.asp?info=re...
# 4    https://www.albemarle.org/navpages.asp?info=re...
# ..                                                 ...
# 253  https://www.ci.staunton.va.us/departments/city...
# 254  https://www.ci.staunton.va.us/departments/city...
# 255  https://www.ci.staunton.va.us/departments/city...
# 256  https://www.ci.staunton.va.us/departments/city...
# 257  https://www.ci.staunton.va.us/departments/city...
#
# [258 rows x 7 columns]

# %%
list(data_df['Locality Name'].unique())
# Out:
# ['Albemarle County',
#  'Alexandria',
#  'Arlington County',
#  'Blacksburg',
#  'Charlottesville',
#  'Chesterfield County',
#  'Commonwealth of Virginia',
#  'Fairfax County',
#  'Hampton',
#  'Harrisonburg',
#  'Henrico County',
#  'Leesburg',
#  'Loudoun County',
#  'Norfolk',
#  'Prince William County',
#  'Richmond',
#  'Roanoke',
#  'Stafford County',
#  'Staunton']

# %%
last_update = client.open('COVID-VA-Locality-Sheet').worksheet("Last Update Message")
data_json = sheet.get_all_records()
last_update_message = worksheet.acell('B1').value
